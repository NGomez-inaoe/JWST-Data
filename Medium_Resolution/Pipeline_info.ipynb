# %%
from astropy.io import fits
from pathlib import Path

# %% [markdown]
# PRISM

# %%
#Define source path where the files are
source = Path('/home/nicolas/Documents/Research/PhD/JWST-Data/PRISM/Spectra1D')
mast_folder = source / 'MAST'

mast_file = mast_folder / 'jw01210-o001_s000104786_nirspec_clear-prism_x1d.fits'
# Open the standard pipeline file (e.g., a _x1d.fits file)
hdul = fits.open(mast_file)

# Access the Primary Header
primary_hdr = hdul[0].header

print(f"Pipeline Version (CAL_VER): {primary_hdr.get('CAL_VER')}")
print(f"CRDS Context (CRDS_CTX): {primary_hdr.get('CRDS_CTX')}")
print(f"Processing Date (DATE): {primary_hdr.get('DATE')}")
# Out:
# Pipeline Version (CAL_VER): 1.20.2
# CRDS Context (CRDS_CTX): jwst_1464.pmap
# Processing Date (DATE): 2025-12-17T13:30:00.350

# %% [markdown]
# Medium Filters

# %%
#Define source path where the files are
source = Path('/home/nicolas/Documents/Research/PhD/JWST-Data/Medium_Resolution/Spectra1D')
jades_folder = source / 'JADES'
mast_folder = source / 'MAST'

mast_file = mast_folder / 'jw01210-o001_s000056849_nirspec_f290lp-g395m_x1d.fits'
# Open the standard pipeline file (e.g., a _x1d.fits file)
hdul = fits.open(mast_file)

# Access the Primary Header
primary_hdr = hdul[0].header

print(f"Pipeline Version (CAL_VER): {primary_hdr.get('CAL_VER')}")
print(f"CRDS Context (CRDS_CTX): {primary_hdr.get('CRDS_CTX')}")
print(f"Processing Date (DATE): {primary_hdr.get('DATE')}")
# Out:
# Pipeline Version (CAL_VER): 1.20.2
# CRDS Context (CRDS_CTX): jwst_1464.pmap
# Processing Date (DATE): 2025-12-17T04:49:27.385

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# DATE    = '2025-12-17T04:49:27.385' / UTC date file created
# ORIGIN  = 'STSCI   '           / Organization responsible for creating file
# TIMESYS = 'UTC     '           / principal time system for time-related keywords
# TIMEUNIT= 's       '           / Default unit applicable to all time values
# FILENAME= 'jw01210-o001_s000056849_nirspec_f290lp-g395m_x1d.fits' / Name of the
# SDP_VER = '2025_4a '           / Data Processing (DP) Software Version
# PRD_VER = 'PRDOPSSOC-072'      / S&OC Project Reference Database (PRD) Version
# OSS_VER = '8.4.14  '           / Observatory Scheduling Software (OSS) Version
# GSC_VER = 'GSC31   '           / Guide Star Catalog (GSC) Version
# CAL_VER = '1.20.2  '           / Calibration Software Version
# ...

# %%
primary_hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# DATE    = '2025-12-17T13:30:00.350' / UTC date file created
# ORIGIN  = 'STSCI   '           / Organization responsible for creating file
# TIMESYS = 'UTC     '           / principal time system for time-related keywords
# TIMEUNIT= 's       '           / Default unit applicable to all time values
# FILENAME= 'jw01210-o001_s000104786_nirspec_clear-prism_x1d.fits' / Name of the f
# SDP_VER = '2025_4a '           / Data Processing (DP) Software Version
# PRD_VER = 'PRDOPSSOC-072'      / S&OC Project Reference Database (PRD) Version
# OSS_VER = '8.4.14  '           / Observatory Scheduling Software (OSS) Version
# GSC_VER = 'GSC31   '           / Guide Star Catalog (GSC) Version
# CAL_VER = '1.20.2  '           / Calibration Software Version
# ...

# %% [markdown]
# ### JADES Versions

# %%
source = Path('/home/nicolas/Documents/Research/PhD/JWST-Data/Medium_Resolution/Spectra1D')
jades_folder = source / 'JADES'

jades_file = jades_folder / 'hlsp_jades_jwst_nirspec_goods-s-deephst-00009452_f170lp-g235m_v1.0_x1d.fits'
# Open the standard pipeline file (e.g., a _x1d.fits file)
hdul = fits.open(jades_file)

# Access the Primary Header
primary_hdr = hdul
primary_hdr

# %%
source = Path('/home/nicolas/Documents/Research/PhD/JWST-Data/Medium_Resolution/Spectra1D')
jades_folder = source / 'Catalogue'

jades_file = jades_folder / 'hlsp_jades_jwst_nirspec_goods-s-deephst-00009452_f170lp-g235m_v1.0_x1d.fits'
# Open the standard pipeline file (e.g., a _x1d.fits file)
hdul = fits.open(jades_file)

# Access the Primary Header
primary_hdr = hdul[0].header
primary_hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# BUNIT   = 'erg s-1 cm-2 AA-1'
# RA      =    53.11583377405873 / Target RA in the APT catalogue
# DEC     =   -27.79754877990375 / Target DEC in the APT catalogue
# TARGET  = '00009452'           / the observation target
# XPOSURE =    8315.667299999999 / [s] effective integration time
# DATE-BEG= '2022-10-20T20:23:09.848' / Date-time start of exposure
# DATE-END= '2022-10-20T21:09:50.915' / Date-time end of exposure
# DOI     = '10.17909/8tdj-8n28'
# RADESYS = 'ICRS    '
# HLSPID  = 'JADES   '
# HLSPLEAD= 'Stefano Carniani, Marcia Rieke'
# HLSPNAME= 'JWST Advanced Deep Extragalactic Survey'
# HLSPTARG= 'GOODS-South-Deep/HST' / Target name
# HLSPVER = '1.0     '
# INSTRUME= 'NIRSpec '
# LICENSE = 'CC BY 4.0'
# LICENURL= 'https://creativecommons.org/licenses/by/4.0/'
# ...
