# %%
import math
from scipy import integrate
# ~ from scipy.integrate import simps
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import pylab as P
#import mpfit
from scipy import stats
from numpy import array, ndarray, sqrt, sin, sinh, maximum
from scipy.integrate import quad
from math import sqrt as msqrt

from astropy.io import fits
from astropy.table import Table

# %%
def plot_spectrum(MAST_file, JADES_file, ID):
  
  
    # ~ fits.open('file.fits')
    t_MAST=Table.read(MAST_file, hdu="EXTRACT1D")
    w_MAST=t_MAST['WAVELENGTH']
    flux_MAST=t_MAST['FLUX'] #flux in Jy
    #z=1
    #rest_w=w/(1+z) #in micras
    #rest_w_Angstrom=rest_w*1e-6/1e-10 # rest wavelength in Angstrom
    w_Angstrom=w_MAST*1e-6/1e-10 # observed wavelength in Angstrom
    flux_ergs = 2.99792458E-05 *flux_MAST / w_Angstrom**2. #flux in erg s^-1 cm^-2 A^-1



    #archivo de JADES
    t_JADES=Table.read(JADES_file, hdu="EXTRACT1D")
    w_JADES=t_JADES['WAVELENGTH']
    flux_JADES=t_JADES['FLUX'] #flux in Jy


    plt.rcParams["figure.figsize"] = (8, 6)
    plt.title(f'ID {ID}, z=', fontsize=18.)
    
    plt.step(w_MAST/1e-4,flux_ergs, label='MAST Data-Archive', color='Blue')
    plt.step(w_JADES/1e-4,flux_JADES, label='JADES Survey', color='Green')
    plt.xlabel(r'$\lambda_{obs}$ [$\AA$]', fontsize=22)
    plt.ylabel(r'FLUX [erg s$^{-1}$ cm$^{-2}$ $\AA^{-1}$]', fontsize=22)
    legend=plt.legend(loc=4,labelspacing=0.1)
    legend=plt.legend(loc='best',labelspacing=0.1)
    plt.setp(legend.get_texts(),fontsize='14')
    plt.savefig(f"PRISM_Plots/ShortList/{ID}.pdf")

# %% [markdown]
# The files below are the one that don't present coincident ID in their names, and correspond to the list of 60 spectra that Ana selected

# %% [markdown]
# ### Starting with 0

# %%
def plot_spectrum(MAST_file, JADES_file, ID, z):
  
  
    # ~ fits.open('file.fits')
    t_MAST=Table.read(MAST_file, hdu="EXTRACT1D")
    w_MAST=t_MAST['WAVELENGTH']
    flux_MAST=t_MAST['FLUX'] #flux in Jy
    #z=1
    #rest_w=w/(1+z) #in micras
    #rest_w_Angstrom=rest_w*1e-6/1e-10 # rest wavelength in Angstrom
    w_Angstrom=w_MAST*1e-6/1e-10 # observed wavelength in Angstrom
    flux_ergs = 2.99792458E-05 *flux_MAST / w_Angstrom**2. #flux in erg s^-1 cm^-2 A^-1



    #archivo de JADES
    t_JADES=Table.read(JADES_file, hdu="EXTRACT1D")
    w_JADES=t_JADES['WAVELENGTH']
    flux_JADES=t_JADES['FLUX'] #flux in Jy


    plt.rcParams["figure.figsize"] = (8, 6)
    plt.title(f'ID {ID}, z={z}', fontsize=18.)
    
    plt.step(w_MAST/1e-4,flux_ergs, label='MAST Data-Archive', color='Blue')
    plt.step(w_JADES/1e-4,flux_JADES, label='JADES Survey', color='Green')
    plt.xlabel(r'$\lambda_{obs}$ [$\AA$]', fontsize=22)
    plt.ylabel(r'FLUX [erg s$^{-1}$ cm$^{-2}$ $\AA^{-1}$]', fontsize=22)
    legend=plt.legend(loc=4,labelspacing=0.1)
    legend=plt.legend(loc='best',labelspacing=0.1)
    plt.setp(legend.get_texts(),fontsize='14')
    plt.savefig(f"PRISM_Plots/ShortList_with_redshift/{ID}.pdf")

# %%
ID="3184"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013491_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.46762

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="3334"
mast_file = './Spectra1D/MAST/jw01210-o001_b000000274_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.70593

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="3968"
mast_file = './Spectra1D/MAST/jw01210-o001_s000000_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.76847043540196

plot_spectrum(mast_file, jades_file, ID, z)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [22], in <cell line: 6>()
#       3 jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
#       4 z = 5.76847043540196
# ----> 6 plot_spectrum(mast_file, jades_file, ID, z)
#
# Input In [21], in plot_spectrum(MAST_file, JADES_file, ID, z)
#       1 def plot_spectrum(MAST_file, JADES_file, ID, z):
#       2
#       3
#       4     # ~ fits.open('file.fits')
# ----> 5     t_MAST=Table.read(MAST_file, hdu="EXTRACT1D")
#       6     w_MAST=t_MAST['WAVELENGTH']
#       7     flux_MAST=t_MAST['FLUX'] #flux in Jy
#
# File ~/Programs/miniconda3/lib/python3.8/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop('units', None)
#      60 descriptions = kwargs.pop('descriptions', None)
# ...

# %%
ID="4197"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009491_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.748809

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="4270"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009489_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z=4.02261238702772

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="4282"
mast_file = './Spectra1D/MAST/jw01210-o001_b000000281_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.599695


plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="4297"
mast_file = './Spectra1D/MAST/jw01210-o001_b000000256_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.712776

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="4404"
mast_file = './Spectra1D/MAST/jw01210-o001_s000015099_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.763688

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="5329"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013301_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.5873007444784

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="5457"
mast_file = './Spectra1D/MAST/jw01210-o001_s000000_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'


plot_spectrum(mast_file, jades_file, ID)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [33], in <cell line: 6>()
#       2 mast_file = './Spectra1D/MAST/jw01210-o001_s000000_nirspec_clear-prism_x1d.fits'
#       3 jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
# ----> 6 plot_spectrum(mast_file, jades_file, ID)
#
# Input In [7], in plot_spectrum(MAST_file, JADES_file, ID)
#       1 def plot_spectrum(MAST_file, JADES_file, ID):
#       2
#       3
#       4     # ~ fits.open('file.fits')
# ----> 5     t_MAST=Table.read(MAST_file, hdu="EXTRACT1D")
#       6     w_MAST=t_MAST['WAVELENGTH']
#       7     flux_MAST=t_MAST['FLUX'] #flux in Jy
#
# File ~/Programs/miniconda3/lib/python3.8/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop('units', None)
# ...

# %%
ID="5759"
mast_file = './Spectra1D/MAST/jw01210-o001_s000005233_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.05189382127941

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="6002"
mast_file = './Spectra1D/MAST/jw01210-o001_s000015125_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.93685818347379

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="6246"
mast_file = './Spectra1D/MAST/jw01210-o001_b000000250_nirspec_clear-prism_x1d.fits'
mast_file = './Spectra1D/MAST/jw01210-o001_b000000258_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.56159788939357


plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="6384"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013877_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.61541238216689

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="7507"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009306_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.04428024657048

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="7624"
mast_file = './Spectra1D/MAST/jw01210-o001_b000000238_nirspec_clear-prism_x1d.fits'
mast_file = './Spectra1D/MAST/jw01210-o001_b000000113_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z  = 4.854

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="7762"
mast_file = './Spectra1D/MAST/jw01210-o001_s000015157_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.14863310108243

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="7809"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009694_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.57819206358422

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="7892"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009451_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z=4.22872754610498

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="7938"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009695_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.80631123887867

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="8013"
mast_file = './Spectra1D/MAST/jw01210-o001_s000006139_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 8.47315

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="8079"
mast_file = './Spectra1D/MAST/jw01210-o001_s000005115_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 7.258982

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="8083"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009515_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.6487198664651

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="8113"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013846_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.90277103561231

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="9422"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013176_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.935895

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="9452"
mast_file = './Spectra1D/MAST/jw01210-o001_s000036976_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.12243857379367

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="9743"
mast_file = './Spectra1D/MAST/jw01210-o001_s000002075_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-0000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.44012039584156

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="16625"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009903_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.630648

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="16745"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013577_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.56655234405774

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="17072"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009849_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.70200977971638

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="17260"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013854_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.88512714601353

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="17566"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009867_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.101534

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="17777"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009858_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.13366013096712

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="18028"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013352_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.73094591607022


plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="18090"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009891_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.77562372049334

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="18846"
mast_file = './Spectra1D/MAST/jw01210-o001_s000013197_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.335054

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="18970"
mast_file = './Spectra1D/MAST/jw01210-o001_s00000_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.72458828704365

plot_spectrum(mast_file, jades_file, ID, z)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [43], in <cell line: 6>()
#       3 jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
#       4 z = 3.72458828704365
# ----> 6 plot_spectrum(mast_file, jades_file, ID, z)
#
# Input In [2], in plot_spectrum(MAST_file, JADES_file, ID, z)
#       1 def plot_spectrum(MAST_file, JADES_file, ID, z):
#       2
#       3
#       4     # ~ fits.open('file.fits')
# ----> 5     t_MAST=Table.read(MAST_file, hdu="EXTRACT1D")
#       6     w_MAST=t_MAST['WAVELENGTH']
#       7     flux_MAST=t_MAST['FLUX'] #flux in Jy
#
# File ~/Programs/miniconda3/lib/python3.8/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop('units', None)
#      60 descriptions = kwargs.pop('descriptions', None)
# ...

# %%
ID="18976"
mast_file = './Spectra1D/MAST/jw01210-o001_s000008253_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.327052

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="19342"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009880_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.974287

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="19519"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009873_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z= 3.60450973158305


plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="19606"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009414_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.88913558713673

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="20961"
mast_file = './Spectra1D/MAST/jw01210-o001_b000000167_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 7.04457065169479

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="22251"
mast_file = './Spectra1D/MAST/jw01210-o001_s000009842_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-000'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.79838391626917

plot_spectrum(mast_file, jades_file, ID, z)

# %% [markdown]
# Now we plot the spectra whose JADES and MAST file names contain same ID, and are in the table

# %%
def plot_spectrum(MAST_file, JADES_file, ID, z):
  
  
    # ~ fits.open('file.fits')
    t_MAST=Table.read(MAST_file, hdu="EXTRACT1D")
    w_MAST=t_MAST['WAVELENGTH']
    flux_MAST=t_MAST['FLUX'] #flux in Jy
    #z=1
    #rest_w=w/(1+z) #in micras
    #rest_w_Angstrom=rest_w*1e-6/1e-10 # rest wavelength in Angstrom
    w_Angstrom=w_MAST*1e-6/1e-10 # observed wavelength in Angstrom
    flux_ergs = 2.99792458E-05 *flux_MAST / w_Angstrom**2. #flux in erg s^-1 cm^-2 A^-1



    #archivo de JADES
    t_JADES=Table.read(JADES_file, hdu="EXTRACT1D")
    w_JADES=t_JADES['WAVELENGTH']
    flux_JADES=t_JADES['FLUX'] #flux in Jy


    plt.rcParams["figure.figsize"] = (8, 6)
    plt.title(f'ID 100{ID}, z={z}', fontsize=18.)
    
    plt.step(w_MAST/1e-4,flux_ergs, label='MAST Data-Archive', color='Blue')
    plt.step(w_JADES/1e-4,flux_JADES, label='JADES Survey', color='Green')
    plt.xlabel(r'$\lambda_{obs}$ [$\AA$]', fontsize=22)
    plt.ylabel(r'FLUX [erg s$^{-1}$ cm$^{-2}$ $\AA^{-1}$]', fontsize=22)
    legend=plt.legend(loc=4,labelspacing=0.1)
    legend=plt.legend(loc='best',labelspacing=0.1)
    plt.setp(legend.get_texts(),fontsize='14')
    plt.savefig(f"PRISM_Plots/ShortList_with_redshift/100{ID}.pdf")

# %%
ID="00626"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.46468607001795

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="01587"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.43070237834676

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="05217"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.8883230178694

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="05447"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.62257640301802

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="09506"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.59928686455817

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="09693"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.28599376348805

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="09848"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.37

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="13545"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 4.03498294164463

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="13609"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 6.928894

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="13618"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.94372301071691

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="13620"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.91753186734937

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="13704"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.919825

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="13905"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 7.197212

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="15338"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.07627227996806

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="16186"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.92792643507394

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="16374"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.50325569707072

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="35295"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 3.58892350772953

plot_spectrum(mast_file, jades_file, ID, z)

# %%
ID="56849"
mast_file = './Spectra1D/MAST/jw01210-o001_s0000'+ID+'_nirspec_clear-prism_x1d.fits'
jades_file = './Spectra1D/JADES/hlsp_jades_jwst_nirspec_goods-s-deephst-100'+ID+'_clear-prism_v1.0_x1d.fits'
z = 5.8142066790736

plot_spectrum(mast_file, jades_file, ID, z)
